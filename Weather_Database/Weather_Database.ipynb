# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size= 2000)
lngs = np.random.uniform(-180, 180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 729

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
test = url + '&q=boston'

city_weather = requests.get(test).json()

city_weather
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 41.56,
#   'feels_like': 36.48,
#   'temp_min': 39.11,
#   'temp_max': 43.92,
#   'pressure': 1000,
#   'humidity': 83},
#  'visibility': 10000,
#  'wind': {'speed': 8.01, 'deg': 267, 'gust': 17},
#  'clouds': {'all': 99},
#  'dt': 1671301012,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1671278872,
#   'sunset': 1671311576},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_weather_desc,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | storsteinnes
# Processing Record 5 of Set 1 | iqaluit
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | beoumi
# Processing Record 9 of Set 1 | avera
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | conde
# Processing Record 12 of Set 1 | kaitangata
# Processing Record 13 of Set 1 | lata
# Processing Record 14 of Set 1 | merrill
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | barreirinhas
# Processing Record 18 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 1 | cozumel
# Processing Record 20 of Set 1 | tornio
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | grand gaube
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | braslav
# City not found. Skipping...
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 1 | las cruces
# Processing Record 30 of Set 1 | la ronge
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | tolbazy
# Processing Record 33 of Set 1 | saint anthony
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 1 | belgrade
# Processing Record 37 of Set 1 | edd
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | inhambane
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | sitka
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | port-gentil
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | elat
# Processing Record 46 of Set 1 | bay roberts
# Processing Record 47 of Set 1 | jaru
# Processing Record 48 of Set 1 | sola
# Processing Record 49 of Set 1 | muros
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | kalianget
# Processing Record 3 of Set 2 | talnakh
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | leshukonskoye
# Processing Record 6 of Set 2 | kruisfontein
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | caravelas
# Processing Record 9 of Set 2 | tuatapere
# Processing Record 10 of Set 2 | viedma
# Processing Record 11 of Set 2 | canakkale
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | mahibadhoo
# Processing Record 14 of Set 2 | yatou
# Processing Record 15 of Set 2 | zhangjiakou
# Processing Record 16 of Set 2 | saint-philippe
# Processing Record 17 of Set 2 | sept-iles
# Processing Record 18 of Set 2 | egvekinot
# Processing Record 19 of Set 2 | neya
# Processing Record 20 of Set 2 | ust-nera
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | atbasar
# Processing Record 23 of Set 2 | iquitos
# Processing Record 24 of Set 2 | torbay
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | effingham
# Processing Record 27 of Set 2 | tupelo
# Processing Record 28 of Set 2 | norman wells
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | saskylakh
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | turukhansk
# Processing Record 33 of Set 2 | labytnangi
# Processing Record 34 of Set 2 | pedasi
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 2 | ushuaia
# Processing Record 38 of Set 2 | dianopolis
# City not found. Skipping...
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | karratha
# Processing Record 41 of Set 2 | biak
# Processing Record 42 of Set 2 | vardo
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | hirara
# Processing Record 45 of Set 2 | lagoa
# Processing Record 46 of Set 2 | nelson bay
# Processing Record 47 of Set 2 | lincoln
# Processing Record 48 of Set 2 | ruteng
# Processing Record 49 of Set 2 | kokopo
# Processing Record 50 of Set 2 | huarmey
# Processing Record 1 of Set 3 | hasaki
# Processing Record 2 of Set 3 | port macquarie
# Processing Record 3 of Set 3 | tasiilaq
# Processing Record 4 of Set 3 | chastoozerye
# City not found. Skipping...
# Processing Record 5 of Set 3 | luderitz
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | isangel
# Processing Record 8 of Set 3 | cape town
# Processing Record 9 of Set 3 | obrenovac
# Processing Record 10 of Set 3 | abu samrah
# Processing Record 11 of Set 3 | seoul
# Processing Record 12 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | arman
# Processing Record 15 of Set 3 | madrid
# Processing Record 16 of Set 3 | bethel
# Processing Record 17 of Set 3 | komsomolskiy
# Processing Record 18 of Set 3 | qaanaaq
# Processing Record 19 of Set 3 | kikwit
# Processing Record 20 of Set 3 | kununurra
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | nampula
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | fairbanks
# Processing Record 25 of Set 3 | beringovskiy
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 28 of Set 3 | faya
# Processing Record 29 of Set 3 | amazar
# Processing Record 30 of Set 3 | fukue
# Processing Record 31 of Set 3 | tezu
# Processing Record 32 of Set 3 | nome
# Processing Record 33 of Set 3 | eston
# Processing Record 34 of Set 3 | nantucket
# Processing Record 35 of Set 3 | moree
# Processing Record 36 of Set 3 | debre sina
# Processing Record 37 of Set 3 | san cristobal
# Processing Record 38 of Set 3 | jamestown
# Processing Record 39 of Set 3 | kasongo-lunda
# Processing Record 40 of Set 3 | lakselv
# Processing Record 41 of Set 3 | cidreira
# Processing Record 42 of Set 3 | naze
# Processing Record 43 of Set 3 | bandarbeyla
# Processing Record 44 of Set 3 | carnarvon
# Processing Record 45 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 3 | cap malheureux
# Processing Record 47 of Set 3 | caceres
# Processing Record 48 of Set 3 | minas
# Processing Record 49 of Set 3 | faanui
# Processing Record 50 of Set 3 | provideniya
# Processing Record 1 of Set 4 | kapaa
# Processing Record 2 of Set 4 | college
# Processing Record 3 of Set 4 | najran
# Processing Record 4 of Set 4 | upernavik
# Processing Record 5 of Set 4 | raurkela
# City not found. Skipping...
# Processing Record 6 of Set 4 | katherine
# Processing Record 7 of Set 4 | san juan
# Processing Record 8 of Set 4 | henties bay
# Processing Record 9 of Set 4 | nyurba
# Processing Record 10 of Set 4 | antalaha
# Processing Record 11 of Set 4 | shelburne
# Processing Record 12 of Set 4 | saint-augustin
# Processing Record 13 of Set 4 | severnyy
# Processing Record 14 of Set 4 | kiama
# Processing Record 15 of Set 4 | nevsehir
# Processing Record 16 of Set 4 | gat
# Processing Record 17 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 4 | soure
# Processing Record 19 of Set 4 | tutoia
# Processing Record 20 of Set 4 | leningradskiy
# Processing Record 21 of Set 4 | preobrazheniye
# Processing Record 22 of Set 4 | severnoye
# Processing Record 23 of Set 4 | paamiut
# Processing Record 24 of Set 4 | tuktoyaktuk
# Processing Record 25 of Set 4 | eirunepe
# Processing Record 26 of Set 4 | cherskiy
# Processing Record 27 of Set 4 | nileshwar
# Processing Record 28 of Set 4 | keuruu
# Processing Record 29 of Set 4 | lexington
# Processing Record 30 of Set 4 | saldanha
# Processing Record 31 of Set 4 | dovers
# Processing Record 32 of Set 4 | alofi
# Processing Record 33 of Set 4 | pomabamba
# Processing Record 34 of Set 4 | manta
# Processing Record 35 of Set 4 | pisco
# Processing Record 36 of Set 4 | umm kaddadah
# Processing Record 37 of Set 4 | sao joao da barra
# Processing Record 38 of Set 4 | touros
# Processing Record 39 of Set 4 | denia
# Processing Record 40 of Set 4 | aksarayskiy
# Processing Record 41 of Set 4 | makakilo city
# Processing Record 42 of Set 4 | hithadhoo
# Processing Record 43 of Set 4 | pundaguitan
# Processing Record 44 of Set 4 | havre-saint-pierre
# Processing Record 45 of Set 4 | gizo
# Processing Record 46 of Set 4 | arcata
# Processing Record 47 of Set 4 | sukhothai
# Processing Record 48 of Set 4 | hami
# Processing Record 49 of Set 4 | souillac
# Processing Record 50 of Set 4 | berlevag
# Processing Record 1 of Set 5 | xai-xai
# Processing Record 2 of Set 5 | moindou
# Processing Record 3 of Set 5 | itarema
# Processing Record 4 of Set 5 | geraldton
# Processing Record 5 of Set 5 | ayaviri
# Processing Record 6 of Set 5 | menongue
# Processing Record 7 of Set 5 | nabire
# Processing Record 8 of Set 5 | salalah
# Processing Record 9 of Set 5 | bengkulu
# Processing Record 10 of Set 5 | sao filipe
# Processing Record 11 of Set 5 | fare
# Processing Record 12 of Set 5 | port alfred
# Processing Record 13 of Set 5 | kiunga
# Processing Record 14 of Set 5 | haimen
# Processing Record 15 of Set 5 | talaya
# Processing Record 16 of Set 5 | henzada
# City not found. Skipping...
# Processing Record 17 of Set 5 | marquard
# Processing Record 18 of Set 5 | saint-joseph
# Processing Record 19 of Set 5 | gilbues
# Processing Record 20 of Set 5 | namatanai
# Processing Record 21 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 5 | juba
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | bela
# Processing Record 26 of Set 5 | arona
# Processing Record 27 of Set 5 | bogatoye
# Processing Record 28 of Set 5 | saint-georges
# Processing Record 29 of Set 5 | musoma
# Processing Record 30 of Set 5 | oranjemund
# Processing Record 31 of Set 5 | penzance
# Processing Record 32 of Set 5 | anadyr
# Processing Record 33 of Set 5 | grindavik
# Processing Record 34 of Set 5 | port lincoln
# Processing Record 35 of Set 5 | port hardy
# Processing Record 36 of Set 5 | acapulco
# Processing Record 37 of Set 5 | klaksvik
# Processing Record 38 of Set 5 | mandan
# Processing Record 39 of Set 5 | arlit
# Processing Record 40 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 41 of Set 5 | zhuhai
# Processing Record 42 of Set 5 | ilulissat
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | sao felix do xingu
# Processing Record 45 of Set 5 | santiago del estero
# Processing Record 46 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 5 | adrar
# Processing Record 48 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 5 | kajaani
# Processing Record 50 of Set 5 | guerrero negro
# Processing Record 1 of Set 6 | fort nelson
# Processing Record 2 of Set 6 | ponnani
# Processing Record 3 of Set 6 | usinsk
# Processing Record 4 of Set 6 | waipawa
# Processing Record 5 of Set 6 | sioux lookout
# Processing Record 6 of Set 6 | columbine
# Processing Record 7 of Set 6 | roald
# Processing Record 8 of Set 6 | eureka
# Processing Record 9 of Set 6 | castilleja de la cuesta
# Processing Record 10 of Set 6 | rocha
# Processing Record 11 of Set 6 | flinders
# Processing Record 12 of Set 6 | ferme-neuve
# Processing Record 13 of Set 6 | muscat
# Processing Record 14 of Set 6 | khatanga
# Processing Record 15 of Set 6 | zlitan
# Processing Record 16 of Set 6 | victoria
# Processing Record 17 of Set 6 | ballina
# Processing Record 18 of Set 6 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 19 of Set 6 | lasa
# Processing Record 20 of Set 6 | guilin
# Processing Record 21 of Set 6 | deep river
# Processing Record 22 of Set 6 | amahai
# Processing Record 23 of Set 6 | dakar
# Processing Record 24 of Set 6 | aswan
# Processing Record 25 of Set 6 | margate
# Processing Record 26 of Set 6 | mahebourg
# Processing Record 27 of Set 6 | beya
# Processing Record 28 of Set 6 | mayumba
# Processing Record 29 of Set 6 | namibe
# Processing Record 30 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 32 of Set 6 | jitra
# Processing Record 33 of Set 6 | tura
# Processing Record 34 of Set 6 | vostok
# Processing Record 35 of Set 6 | lower hutt
# Processing Record 36 of Set 6 | ahipara
# Processing Record 37 of Set 6 | praia da vitoria
# Processing Record 38 of Set 6 | sobolevo
# Processing Record 39 of Set 6 | merauke
# Processing Record 40 of Set 6 | asau
# Processing Record 41 of Set 6 | port blair
# Processing Record 42 of Set 6 | poum
# Processing Record 43 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 44 of Set 6 | price
# Processing Record 45 of Set 6 | coihaique
# Processing Record 46 of Set 6 | pevek
# Processing Record 47 of Set 6 | heihe
# Processing Record 48 of Set 6 | bathsheba
# Processing Record 49 of Set 6 | koumac
# Processing Record 50 of Set 6 | rawson
# Processing Record 1 of Set 7 | bonavista
# Processing Record 2 of Set 7 | awbari
# Processing Record 3 of Set 7 | petropavlovka
# Processing Record 4 of Set 7 | sangar
# Processing Record 5 of Set 7 | bundibugyo
# Processing Record 6 of Set 7 | nikolayevsk-na-amure
# Processing Record 7 of Set 7 | maniitsoq
# Processing Record 8 of Set 7 | el retorno
# Processing Record 9 of Set 7 | camana
# Processing Record 10 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 7 | mastic beach
# Processing Record 13 of Set 7 | coquimbo
# Processing Record 14 of Set 7 | do gonbadan
# Processing Record 15 of Set 7 | panzhihua
# Processing Record 16 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 7 | dikson
# Processing Record 18 of Set 7 | chimore
# Processing Record 19 of Set 7 | ancud
# Processing Record 20 of Set 7 | ardahan
# Processing Record 21 of Set 7 | ashti
# Processing Record 22 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 7 | takaungu
# Processing Record 25 of Set 7 | kavieng
# Processing Record 26 of Set 7 | lebu
# Processing Record 27 of Set 7 | yulara
# Processing Record 28 of Set 7 | nanortalik
# Processing Record 29 of Set 7 | pacific grove
# Processing Record 30 of Set 7 | yellamanchili
# City not found. Skipping...
# Processing Record 31 of Set 7 | yerofey pavlovich
# Processing Record 32 of Set 7 | river falls
# Processing Record 33 of Set 7 | atar
# Processing Record 34 of Set 7 | buala
# Processing Record 35 of Set 7 | narsaq
# Processing Record 36 of Set 7 | bukama
# Processing Record 37 of Set 7 | oussouye
# Processing Record 38 of Set 7 | san andres
# Processing Record 39 of Set 7 | port lavaca
# Processing Record 40 of Set 7 | jumla
# Processing Record 41 of Set 7 | vredendal
# Processing Record 42 of Set 7 | greytown
# Processing Record 43 of Set 7 | san carlos de bariloche
# Processing Record 44 of Set 7 | loncoche
# Processing Record 45 of Set 7 | porto novo
# Processing Record 46 of Set 7 | ambilobe
# Processing Record 47 of Set 7 | nikolskoye
# Processing Record 48 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 7 | xining
# Processing Record 50 of Set 7 | santa cruz
# Processing Record 1 of Set 8 | miyako
# Processing Record 2 of Set 8 | praya
# Processing Record 3 of Set 8 | avarua
# Processing Record 4 of Set 8 | walvis bay
# Processing Record 5 of Set 8 | sinop
# Processing Record 6 of Set 8 | tessalit
# Processing Record 7 of Set 8 | ruian
# City not found. Skipping...
# Processing Record 8 of Set 8 | kollumerland
# City not found. Skipping...
# Processing Record 9 of Set 8 | sur
# Processing Record 10 of Set 8 | jalu
# Processing Record 11 of Set 8 | hambantota
# Processing Record 12 of Set 8 | bridlington
# Processing Record 13 of Set 8 | ngunguru
# Processing Record 14 of Set 8 | bahia honda
# Processing Record 15 of Set 8 | marica
# Processing Record 16 of Set 8 | port hedland
# Processing Record 17 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 8 | vestmannaeyjar
# Processing Record 19 of Set 8 | san lawrenz
# Processing Record 20 of Set 8 | norden
# Processing Record 21 of Set 8 | te anau
# Processing Record 22 of Set 8 | manaus
# Processing Record 23 of Set 8 | araouane
# Processing Record 24 of Set 8 | tomatlan
# Processing Record 25 of Set 8 | emborion
# Processing Record 26 of Set 8 | camacha
# Processing Record 27 of Set 8 | broken hill
# Processing Record 28 of Set 8 | rio grande
# Processing Record 29 of Set 8 | juneau
# Processing Record 30 of Set 8 | saint george
# Processing Record 31 of Set 8 | dudinka
# Processing Record 32 of Set 8 | petersburg
# Processing Record 33 of Set 8 | aksu
# Processing Record 34 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 8 | lavrentiya
# Processing Record 36 of Set 8 | high rock
# Processing Record 37 of Set 8 | aksum
# Processing Record 38 of Set 8 | uchaly
# Processing Record 39 of Set 8 | tagusao
# Processing Record 40 of Set 8 | kalmunai
# Processing Record 41 of Set 8 | sonari
# Processing Record 42 of Set 8 | warwick
# Processing Record 43 of Set 8 | esperance
# Processing Record 44 of Set 8 | campos gerais
# Processing Record 45 of Set 8 | nouadhibou
# Processing Record 46 of Set 8 | el balyana
# City not found. Skipping...
# Processing Record 47 of Set 8 | bara
# Processing Record 48 of Set 8 | hamilton
# Processing Record 49 of Set 8 | guye
# Processing Record 50 of Set 8 | bilibino
# Processing Record 1 of Set 9 | marienburg
# Processing Record 2 of Set 9 | derry
# Processing Record 3 of Set 9 | adeje
# Processing Record 4 of Set 9 | coracao de jesus
# Processing Record 5 of Set 9 | svetlyy
# Processing Record 6 of Set 9 | tazovskiy
# Processing Record 7 of Set 9 | akureyri
# Processing Record 8 of Set 9 | kinston
# Processing Record 9 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 9 | laguna
# Processing Record 11 of Set 9 | witbank
# Processing Record 12 of Set 9 | half moon bay
# Processing Record 13 of Set 9 | kavaratti
# Processing Record 14 of Set 9 | nagornyy
# Processing Record 15 of Set 9 | okakarara
# Processing Record 16 of Set 9 | skjervoy
# Processing Record 17 of Set 9 | cabo rojo
# Processing Record 18 of Set 9 | uttarkashi
# Processing Record 19 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 9 | hay river
# Processing Record 21 of Set 9 | shreveport
# Processing Record 22 of Set 9 | mehamn
# Processing Record 23 of Set 9 | blytheville
# Processing Record 24 of Set 9 | matamoros
# Processing Record 25 of Set 9 | mount gambier
# Processing Record 26 of Set 9 | brigantine
# Processing Record 27 of Set 9 | cayenne
# Processing Record 28 of Set 9 | rio gallegos
# Processing Record 29 of Set 9 | benguela
# Processing Record 30 of Set 9 | pietersburg
# Processing Record 31 of Set 9 | chaihe
# Processing Record 32 of Set 9 | basco
# Processing Record 33 of Set 9 | port augusta
# Processing Record 34 of Set 9 | korsakov
# Processing Record 35 of Set 9 | manuk mangkaw
# Processing Record 36 of Set 9 | sao jose da coroa grande
# Processing Record 37 of Set 9 | aklavik
# Processing Record 38 of Set 9 | sorland
# Processing Record 39 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 9 | erenhot
# Processing Record 41 of Set 9 | bambous virieux
# Processing Record 42 of Set 9 | tautira
# Processing Record 43 of Set 9 | port hueneme
# Processing Record 44 of Set 9 | boende
# Processing Record 45 of Set 9 | murwara
# Processing Record 46 of Set 9 | podosinovets
# Processing Record 47 of Set 9 | vila franca do campo
# Processing Record 48 of Set 9 | pignon
# Processing Record 49 of Set 9 | luba
# Processing Record 50 of Set 9 | plouzane
# Processing Record 1 of Set 10 | quebrada larga
# Processing Record 2 of Set 10 | waingapu
# Processing Record 3 of Set 10 | sioux city
# Processing Record 4 of Set 10 | zatoka
# Processing Record 5 of Set 10 | cap-aux-meules
# Processing Record 6 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 7 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 8 of Set 10 | upata
# Processing Record 9 of Set 10 | pointe-noire
# Processing Record 10 of Set 10 | weston
# Processing Record 11 of Set 10 | gogrial
# Processing Record 12 of Set 10 | negombo
# Processing Record 13 of Set 10 | alice springs
# Processing Record 14 of Set 10 | tariba
# Processing Record 15 of Set 10 | zhangye
# Processing Record 16 of Set 10 | glens falls
# Processing Record 17 of Set 10 | san rafael
# Processing Record 18 of Set 10 | sinyavino
# Processing Record 19 of Set 10 | snejbjerg
# Processing Record 20 of Set 10 | qibili
# City not found. Skipping...
# Processing Record 21 of Set 10 | ahuimanu
# Processing Record 22 of Set 10 | sinnamary
# Processing Record 23 of Set 10 | coralville
# Processing Record 24 of Set 10 | chalatenango
# Processing Record 25 of Set 10 | marawi
# Processing Record 26 of Set 10 | flin flon
# Processing Record 27 of Set 10 | jiangyou
# Processing Record 28 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 10 | atagay
# Processing Record 30 of Set 10 | padang
# Processing Record 31 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 32 of Set 10 | qarqin
# Processing Record 33 of Set 10 | riyadh
# Processing Record 34 of Set 10 | alcudia
# Processing Record 35 of Set 10 | praia
# Processing Record 36 of Set 10 | ust-kulom
# Processing Record 37 of Set 10 | mar del plata
# Processing Record 38 of Set 10 | padre bernardo
# Processing Record 39 of Set 10 | kutum
# Processing Record 40 of Set 10 | pine bluff
# Processing Record 41 of Set 10 | quebec
# Processing Record 42 of Set 10 | fortuna
# Processing Record 43 of Set 10 | aksarka
# Processing Record 44 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 10 | thunder bay
# Processing Record 46 of Set 10 | okha
# Processing Record 47 of Set 10 | hovd
# Processing Record 48 of Set 10 | elliot
# Processing Record 49 of Set 10 | bamiantong
# Processing Record 50 of Set 10 | gwadar
# Processing Record 1 of Set 11 | shadegan
# Processing Record 2 of Set 11 | jizan
# Processing Record 3 of Set 11 | santarem
# Processing Record 4 of Set 11 | buritis
# Processing Record 5 of Set 11 | singkang
# Processing Record 6 of Set 11 | olafsvik
# Processing Record 7 of Set 11 | byron bay
# Processing Record 8 of Set 11 | santa comba
# Processing Record 9 of Set 11 | negele
# City not found. Skipping...
# Processing Record 10 of Set 11 | khasan
# Processing Record 11 of Set 11 | bud
# Processing Record 12 of Set 11 | monze
# Processing Record 13 of Set 11 | nara
# Processing Record 14 of Set 11 | haines junction
# Processing Record 15 of Set 11 | dania beach
# Processing Record 16 of Set 11 | srandakan
# Processing Record 17 of Set 11 | newport
# Processing Record 18 of Set 11 | vila velha
# Processing Record 19 of Set 11 | mirskoy
# Processing Record 20 of Set 11 | kroonstad
# Processing Record 21 of Set 11 | yaan
# Processing Record 22 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 11 | aiquile
# Processing Record 24 of Set 11 | lamu
# Processing Record 25 of Set 11 | shimoda
# Processing Record 26 of Set 11 | kupang
# Processing Record 27 of Set 11 | majitha
# Processing Record 28 of Set 11 | yafran
# Processing Record 29 of Set 11 | yeletskiy
# City not found. Skipping...
# Processing Record 30 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 11 | kaduqli
# Processing Record 32 of Set 11 | keflavik
# Processing Record 33 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 34 of Set 11 | batagay-alyta
# Processing Record 35 of Set 11 | igarka
# Processing Record 36 of Set 11 | kunming
# Processing Record 37 of Set 11 | holly hill
# Processing Record 38 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 39 of Set 11 | san patricio
# Processing Record 40 of Set 11 | pasni
# Processing Record 41 of Set 11 | saint-felicien
# Processing Record 42 of Set 11 | el sauzal
# Processing Record 43 of Set 11 | uglegorsk
# Processing Record 44 of Set 11 | mocuba
# Processing Record 45 of Set 11 | gamba
# Processing Record 46 of Set 11 | kawalu
# Processing Record 47 of Set 11 | ucluelet
# Processing Record 48 of Set 11 | lake city
# Processing Record 49 of Set 11 | kenai
# Processing Record 50 of Set 11 | kalevala
# Processing Record 1 of Set 12 | litoral del san juan
# City not found. Skipping...
# Processing Record 2 of Set 12 | vanavara
# Processing Record 3 of Set 12 | sao bento
# Processing Record 4 of Set 12 | pangnirtung
# Processing Record 5 of Set 12 | anantnag
# Processing Record 6 of Set 12 | carupano
# Processing Record 7 of Set 12 | losinyy
# Processing Record 8 of Set 12 | grants
# Processing Record 9 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 12 | lakes entrance
# Processing Record 11 of Set 12 | sahuaripa
# Processing Record 12 of Set 12 | hohhot
# Processing Record 13 of Set 12 | tiznit
# Processing Record 14 of Set 12 | kayerkan
# Processing Record 15 of Set 12 | codrington
# Processing Record 16 of Set 12 | huadian
# Processing Record 17 of Set 12 | bairiki
# Processing Record 18 of Set 12 | usogorsk
# Processing Record 19 of Set 12 | sortland
# Processing Record 20 of Set 12 | seymchan
# Processing Record 21 of Set 12 | serebryansk
# Processing Record 22 of Set 12 | katsuura
# Processing Record 23 of Set 12 | srednekolymsk
# Processing Record 24 of Set 12 | aras
# Processing Record 25 of Set 12 | itacoatiara
# Processing Record 26 of Set 12 | makat
# Processing Record 27 of Set 12 | maceio
# Processing Record 28 of Set 12 | nhulunbuy
# Processing Record 29 of Set 12 | sao gabriel da cachoeira
# Processing Record 30 of Set 12 | muzhi
# Processing Record 31 of Set 12 | kapoeta
# Processing Record 32 of Set 12 | pedernales
# Processing Record 33 of Set 12 | panorama
# Processing Record 34 of Set 12 | liaocheng
# Processing Record 35 of Set 12 | tayoltita
# Processing Record 36 of Set 12 | nioro
# Processing Record 37 of Set 12 | ixtapa
# Processing Record 38 of Set 12 | cockburn town
# Processing Record 39 of Set 12 | yangjiang
# Processing Record 40 of Set 12 | maun
# Processing Record 41 of Set 12 | trojanovice
# Processing Record 42 of Set 12 | abha
# Processing Record 43 of Set 12 | zholymbet
# Processing Record 44 of Set 12 | mayo
# Processing Record 45 of Set 12 | cairns
# Processing Record 46 of Set 12 | rudnytsya
# City not found. Skipping...
# Processing Record 47 of Set 12 | los llanos de aridane
# Processing Record 48 of Set 12 | agutaya
# Processing Record 49 of Set 12 | hastings
# Processing Record 50 of Set 12 | fort-shevchenko
# Processing Record 1 of Set 13 | dibaya
# City not found. Skipping...
# Processing Record 2 of Set 13 | sambava
# Processing Record 3 of Set 13 | honiara
# Processing Record 4 of Set 13 | kvitok
# Processing Record 5 of Set 13 | iguape
# Processing Record 6 of Set 13 | nizwa
# Processing Record 7 of Set 13 | semey
# Processing Record 8 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 13 | umuarama
# Processing Record 10 of Set 13 | west bay
# Processing Record 11 of Set 13 | pajapan
# Processing Record 12 of Set 13 | tazmalt
# Processing Record 13 of Set 13 | nongpoh
# Processing Record 14 of Set 13 | poya
# Processing Record 15 of Set 13 | san luis
# Processing Record 16 of Set 13 | siniscola
# Processing Record 17 of Set 13 | yumen
# Processing Record 18 of Set 13 | clyde river
# Processing Record 19 of Set 13 | zambezi
# Processing Record 20 of Set 13 | temple
# Processing Record 21 of Set 13 | almaznyy
# Processing Record 22 of Set 13 | kloulklubed
# Processing Record 23 of Set 13 | bayan
# Processing Record 24 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 13 | teya
# Processing Record 26 of Set 13 | klyuchi
# Processing Record 27 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 28 of Set 13 | vila
# Processing Record 29 of Set 13 | fallon
# Processing Record 30 of Set 13 | yar-sale
# Processing Record 31 of Set 13 | jacareacanga
# Processing Record 32 of Set 13 | liwale
# Processing Record 33 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 13 | zhuanghe
# Processing Record 35 of Set 13 | veseloyarsk
# Processing Record 36 of Set 13 | cochabamba
# Processing Record 37 of Set 13 | jasper
# Processing Record 38 of Set 13 | ukiah
# Processing Record 39 of Set 13 | kant
# Processing Record 40 of Set 13 | kemijarvi
# Processing Record 41 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 42 of Set 13 | maturin
# Processing Record 43 of Set 13 | kormilovka
# Processing Record 44 of Set 13 | terrace
# Processing Record 45 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 46 of Set 13 | chaiya
# Processing Record 47 of Set 13 | beloha
# Processing Record 48 of Set 13 | bang saphan
# Processing Record 49 of Set 13 | lively
# Processing Record 50 of Set 13 | agucadoura
# Processing Record 1 of Set 14 | zhigansk
# Processing Record 2 of Set 14 | sorkjosen
# Processing Record 3 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 5 of Set 14 | kyra
# Processing Record 6 of Set 14 | kisanga
# Processing Record 7 of Set 14 | antoing
# Processing Record 8 of Set 14 | mariental
# Processing Record 9 of Set 14 | ikom
# Processing Record 10 of Set 14 | lorengau
# Processing Record 11 of Set 14 | las vegas
# Processing Record 12 of Set 14 | oranjestad
# Processing Record 13 of Set 14 | sabang
# Processing Record 14 of Set 14 | kaohsiung
# Processing Record 15 of Set 14 | chicama
# Processing Record 16 of Set 14 | pasighat
# Processing Record 17 of Set 14 | kenora
# Processing Record 18 of Set 14 | jiayuguan
# Processing Record 19 of Set 14 | kidal
# Processing Record 20 of Set 14 | hurricane
# Processing Record 21 of Set 14 | pucallpa
# Processing Record 22 of Set 14 | bednodemyanovsk
# City not found. Skipping...
# Processing Record 23 of Set 14 | taltal
# Processing Record 24 of Set 14 | buenos aires
# Processing Record 25 of Set 14 | tual
# Processing Record 26 of Set 14 | ossora
# Processing Record 27 of Set 14 | norwich
# Processing Record 28 of Set 14 | dunedin
# Processing Record 29 of Set 14 | boshan
# Processing Record 30 of Set 14 | warrington
# Processing Record 31 of Set 14 | nagireddipalle
# City not found. Skipping...
# Processing Record 32 of Set 14 | we
# City not found. Skipping...
# Processing Record 33 of Set 14 | wanning
# Processing Record 34 of Set 14 | yingcheng
# Processing Record 35 of Set 14 | ambon
# Processing Record 36 of Set 14 | lompoc
# Processing Record 37 of Set 14 | sekondi
# Processing Record 38 of Set 14 | takoradi
# Processing Record 39 of Set 14 | tocopilla
# Processing Record 40 of Set 14 | carutapera
# Processing Record 41 of Set 14 | kahului
# Processing Record 42 of Set 14 | kuusamo
# Processing Record 43 of Set 14 | felanitx
# Processing Record 44 of Set 14 | mathathane
# Processing Record 45 of Set 14 | celestun
# Processing Record 46 of Set 14 | comapa
# Processing Record 47 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 48 of Set 14 | hengshui
# Processing Record 49 of Set 14 | lerwick
# Processing Record 50 of Set 14 | vilhena
# Processing Record 1 of Set 15 | parabel
# Processing Record 2 of Set 15 | kletskaya
# Processing Record 3 of Set 15 | santander
# Processing Record 4 of Set 15 | burdur
# Processing Record 5 of Set 15 | gorom-gorom
# Processing Record 6 of Set 15 | lukovetskiy
# Processing Record 7 of Set 15 | bulungu
# Processing Record 8 of Set 15 | matara
# Processing Record 9 of Set 15 | balkanabat
# Processing Record 10 of Set 15 | keetmanshoop
# Processing Record 11 of Set 15 | smiltene
# Processing Record 12 of Set 15 | brae
# Processing Record 13 of Set 15 | kukes
# Processing Record 14 of Set 15 | tabuk
# Processing Record 15 of Set 15 | banda aceh
# Processing Record 16 of Set 15 | nova olinda do norte
# Processing Record 17 of Set 15 | jhabua
# Processing Record 18 of Set 15 | laiyang
# Processing Record 19 of Set 15 | bjornevatn
# Processing Record 20 of Set 15 | rajshahi
# Processing Record 21 of Set 15 | gamboma
# Processing Record 22 of Set 15 | mariinsk
# Processing Record 23 of Set 15 | russell
# Processing Record 24 of Set 15 | kokkola
# Processing Record 25 of Set 15 | soller
# Processing Record 26 of Set 15 | urumqi
# Processing Record 27 of Set 15 | quiindy
# Processing Record 28 of Set 15 | wucheng
# Processing Record 29 of Set 15 | linhares
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 661

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas -53.1500  -70.9167     55.51        44           0
# 1          Hilo  19.7297 -155.0900     78.12        77           0
# 2  Storsteinnes  69.2408   19.2344     25.38        82          91
# 3       Iqaluit  63.7506  -68.5145     26.33        68          75
# 4         Bluff -46.6000  168.3333     52.81        84         100
# 5        Barrow  71.2906 -156.7887     -5.78        77          75
# 6        Beoumi   7.6736   -5.5764     84.15        42          22
# 7         Avera  33.1940  -82.5271     53.11        57          98
# 8     Busselton -33.6500  115.3333     63.18        71          12
# 9         Conde  -7.2597  -34.9075     85.46        51          40
#
#    Wind Speed Country       Description                 Date
# 0       23.02      CL         clear sky  2022-12-17 18:24:17
# 1        5.75      US         clear sky  2022-12-17 18:25:48
# 2        4.68      NO   overcast clouds  2022-12-17 18:25:49
# 3       11.50      CA     broken clouds  2022-12-17 18:25:49
# 4       15.26      NZ   overcast clouds  2022-12-17 18:25:49
# 5       14.97      US     broken clouds  2022-12-17 18:25:50
# 6        3.76      CI        few clouds  2022-12-17 18:25:50
# 7        8.90      US   overcast clouds  2022-12-17 18:25:50
# 8       14.74      AU        few clouds  2022-12-17 18:25:51
# 9       10.36      BR  scattered clouds  2022-12-17 18:25:51

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     55.51        44           0
# 1          Hilo      US  19.7297 -155.0900     78.12        77           0
# 2  Storsteinnes      NO  69.2408   19.2344     25.38        82          91
# 3       Iqaluit      CA  63.7506  -68.5145     26.33        68          75
# 4         Bluff      NZ -46.6000  168.3333     52.81        84         100
# 5        Barrow      US  71.2906 -156.7887     -5.78        77          75
# 6        Beoumi      CI   7.6736   -5.5764     84.15        42          22
# 7         Avera      US  33.1940  -82.5271     53.11        57          98
# 8     Busselton      AU -33.6500  115.3333     63.18        71          12
# 9         Conde      BR  -7.2597  -34.9075     85.46        51          40
#
#    Wind Speed       Description
# 0       23.02         clear sky
# 1        5.75         clear sky
# 2        4.68   overcast clouds
# 3       11.50     broken clouds
# 4       15.26   overcast clouds
# 5       14.97     broken clouds
# 6        3.76        few clouds
# 7        8.90   overcast clouds
# 8       14.74        few clouds
# 9       10.36  scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
